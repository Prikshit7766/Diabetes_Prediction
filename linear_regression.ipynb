# %% [markdown]
# <a href="https://colab.research.google.com/github/Prikshit7766/Ml_class/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT="/content/drive/MyDrive/day 1"

# %%
import os 
os.chdir(ROOT)

# %%
# !ls
# Out:
# linear_regression.ipynb  test.txt

# %%
assert ROOT == os.getcwd()

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/day 1'

# %%
with open("test.txt", "w") as f:
  f.writelines("Hello everyone")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/data/Chinas Population En.csv')
df.head()
# Out:
#    Unnamed: 0  At the end of the total population (ten thousand people)  \
# 0        2021                                             141260
# 1        2020                                             141212
# 2        2019                                             141008
# 3        2018                                             140541
# 4        2017                                             140011
#
#    The male population (ten thousand people)  \
# 0                                      72311
# 1                                      72357
# 2                                      72039
# 3                                      71864
# 4                                      71650
#
#    Female population (ten thousand people)  \
# 0                                    68949
# 1                                    68855
# 2                                    68969
# 3                                    68677
# 4                                    68361
#
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/data/Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df['Total_spent'] = df['TV'] + df['Radio'] + df['Newspaper']
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  Total_spent
# 0           1  230.1   37.8       69.2   22.1        337.1
# 1           2   44.5   39.3       45.1   10.4        128.9
# 2           3   17.2   45.9       69.3    9.3        132.4
# 3           4  151.5   41.3       58.5   18.5        251.3
# 4           5  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df,x='Total_spent',y='Sales')

# %%
sns.regplot(data=df,x='Total_spent',y='Sales',color="black")

# %%
x=df["Total_spent"]
y=df["Sales"]

# %%
#help(sns.regplot)

# %%
np.polyfit(x,y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
# these are like my Q1 and Q0 values ie slope and intercept respectively

# %%
potential_spend=np.linspace(0,500,100)
potential_spend #x values for to plot line of best fit
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
# as we know 
#y=mx+c
predicted_sales=0.04868788*potential_spend+4.24302822

# %%
sns.scatterplot(x='Total_spent',y="Sales",data=df) #actual data on which we are working on !!
#scatter plot
plt.plot(potential_spend,predicted_sales,color="red")
#ploting the line of best fit

# %%
spend=200
predicted_sales=0.04868788*spend+4.24302822
predicted_sales
# Out:
# 13.98060422

# %%
#polynomial regression
np.polyfit(x,y,deg=3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
#equation be like
#Y = B3x**3 + B2x**2 + B3x + B0
pot_spend=np.linspace(0,500,100)

# %%
pred_sales=3.07615033e-07*pot_spend**3+ -1.89392449e-04*pot_spend**2+   8.20886302e-02*pot_spend**1+ 2.70495053e+00

# %%
sns.scatterplot(x='Total_spent',y="Sales",data=df) #actual data on which we are working on !!
#scatter plot
plt.plot(pot_spend,pred_sales,color="red")
#ploting the line of best fit

# %%
fig,axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['Sales'], 'o')
axes[0].set_ylabel("sales")
axes[0].set_title("TV Spend")


axes[1].plot(df['Radio'], df['Sales'], 'o')
axes[1].set_ylabel("Sales")
axes[1].set_title("Radio Spend")

axes[2].plot(df['Newspaper'], df['Sales'], 'o')
axes[2].set_ylabel("sales")
axes[2].set_title("Newspaper Spend")
# Out:
# Text(0.5, 1.0, 'Newspaper Spend')

# %%
sns.pairplot(df)

# %%
df = pd.read_csv('/content/drive/MyDrive/data/Advertising.csv')
df.head()
df['Total_spent'] = df['TV'] + df['Radio'] + df['Newspaper']
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  Total_spent
# 0           1  230.1   37.8       69.2   22.1        337.1
# 1           2   44.5   39.3       45.1   10.4        128.9
# 2           3   17.2   45.9       69.3    9.3        132.4
# 3           4  151.5   41.3       58.5   18.5        251.3
# 4           5  180.8   10.8       58.4   12.9        250.0

# %%
x= df.drop(['Sales','Total_spent'],axis=1)

# %%
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=101)

# %%
x_train.head()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 154         155  187.8   21.1        9.5
# 114         115   78.2   46.8       34.5
# 118         119  125.7   36.9       79.2
# 64           65  131.1   42.8       28.9
# 165         166  234.5    3.4       84.8

# %%
len(x_train)
# Out:
# 134

# %%
len(df)
# Out:
# 200

# %%
len(x_test)
# Out:
# 66

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_pred=model.predict(x_test)

# %%
test_pred
# Out:
# array([15.80815781, 19.59478441, 11.65318196, 16.90616123,  9.29324576,
#         6.9576299 , 20.42896073, 17.38903208,  9.71239699, 19.02565524,
#        12.19530761, 13.90394338, 13.56268927, 21.28245943, 18.16280173,
#         9.8029787 , 15.86148562,  7.98422928,  7.35967591, 20.53359563,
#         7.56171668, 17.98628427, 24.33018531, 22.83159769,  8.15767462,
#        12.85395477, 21.67491664,  7.94800332, 12.21190438, 12.65690113,
#        10.93612933, 19.06485468, 10.1732291 ,  6.92187944, 17.4389691 ,
#         8.03313785,  9.19227486,  8.03928278, 10.29570519, 10.45969989,
#        13.07752697,  9.54788603, 10.06209218,  7.92127873, 11.60672343,
#        10.34896889,  9.049393  , 16.39838593, 13.52531132, 20.95478715,
#        12.71188323, 14.18676282, 17.60078023, 10.98318481, 12.91935341,
#         5.37758202, 23.46028051, 12.2863173 , 19.03424647, 15.34584786,
#        15.20639729, 23.63877152,  6.7295472 , 19.97196922, 13.89679894,
#        21.08678567])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
sns.histplot(data=df,x='Sales',bins=20)

# %%
mean_absolute_error(y_test,test_pred)
# Out:
# 1.2838781046602448

# %%
z=mean_squared_error(y_test,test_pred)

# %%
z
# Out:
# 2.4752617168438413

# %%
np.sqrt(z)
# Out:
# 1.5732964491296106

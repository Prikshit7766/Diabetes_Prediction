# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data =pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Diabetes_Prediction\Diabetes_Prediction\diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
#see the info about the data structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#to see is there is a missing value or not

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#this data is showing no missing values ,but some of the column are  having lots zeros .. 
#so the model won't be learning anything
#so this might create some problem while creating some kind of prediction models
#so we have handel this kind of situation

# %%
#checking the correlation 
import seaborn as sns
import matplotlib.pyplot as plt
#get correlation of each feature in data set
corrmat=data.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
#plot heat map for each feature 
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#another way of checking the correlation

# %%
# import modules
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
  
# import file with data

  
# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# plotting correlation heatmap
dataplot = sb.heatmap(data.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
mp.show()

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_true_count=len(data.loc[data["Outcome"]==True])
diabetes_false_count=len(data.loc[data["Outcome"]==False])
(diabetes_true_count,diabetes_false_count)
# Out:
# (268, 500)

# %%
feature_column=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]
predicted_class=["Outcome"]
x=data[feature_column].values
y=data[predicted_class].values

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
#now we check how many zeros are present in each and every column

# %%
print("total numbers of rows:{0}",format(len(data)))
print("numbers of rows missing Glucose:{0}",format(len(data.loc[data["Glucose"]==0])) )
print("numbers of rows missing BloodPressure:{0}",format(len(data.loc[data["BloodPressure"]==0]))) 
print("numbers of rows missing Insulin:{0}",format(len(data.loc[data["Insulin"]==0])) )
print("numbers of rows missing BMI:{0}",format(len(data.loc[data["BMI"]==0])) )
print("numbers of rows missing Age:{0}",format(len(data.loc[data["Age"]==0])) )
print("numbers of rows missing DiabetesPedigreeFunction:{0}",format(len(data.loc[data["DiabetesPedigreeFunction"]==0])) )
# Out:
# total numbers of rows:{0} 768
# numbers of rows missing Glucose:{0} 5
# numbers of rows missing BloodPressure:{0} 35
# numbers of rows missing Insulin:{0} 374
# numbers of rows missing BMI:{0} 11
# numbers of rows missing Age:{0} 0
# numbers of rows missing DiabetesPedigreeFunction:{0} 0

# %%
#in  insuline  there are 374 zeros ,so we are going to do mean imputation

# %%
from sklearn.impute import SimpleImputer
help(SimpleImputer)
# Out:
# Help on class SimpleImputer in module sklearn.impute._base:
#
# class SimpleImputer(_BaseImputer)
#  |  SimpleImputer(*, missing_values=nan, strategy='mean', fill_value=None, verbose=0, copy=True, add_indicator=False)
#  |
#  |  Imputation transformer for completing missing values.
#  |
#  |  Read more in the :ref:`User Guide <impute>`.
#  |
#  |  .. versionadded:: 0.20
#  |     `SimpleImputer` replaces the previous `sklearn.preprocessing.Imputer`
#  |     estimator which is now removed.
#  |
#  |  Parameters
#  |  ----------
#  |  missing_values : int, float, str, np.nan or None, default=np.nan
#  |      The placeholder for the missing values. All occurrences of
#  |      `missing_values` will be imputed. For pandas' dataframes with
#  |      nullable integer dtypes with missing values, `missing_values`
#  |      should be set to `np.nan`, since `pd.NA` will be converted to `np.nan`.
#  |
#  |  strategy : str, default='mean'
#  |      The imputation strategy.
#  |
# ...

# %%
fill_values=SimpleImputer(missing_values=0,strategy="mean")
x_train=fill_values.fit_transform(x_train)
x_test=fill_values.transform(x_test)

# %%
#now ALGORITHM OF LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression(random_state=0)

# %%
clf.fit(x_train,y_train)
# Out:
# C:\Users\HP\Anaconda3\envs\Diabetes_Prediction\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP\Anaconda3\envs\Diabetes_Prediction\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(random_state=0)

# %%
predict_train_data=clf.predict(x_test)

# %%
from sklearn import metrics

# %%
print("accuracy={0:.3f}".format(metrics.accuracy_score(y_test,predict_train_data)))
# Out:
# accuracy=0.779

# %%
# now we do hyperparameter tunning by gridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
import warnings

# %%
help(warnings)
# Out:
# Help on module warnings:
#
# NAME
#     warnings - Python part of the warnings subsystem.
#
# CLASSES
#     builtins.object
#         catch_warnings
#
#     class catch_warnings(builtins.object)
#      |  catch_warnings(*, record=False, module=None)
#      |
#      |  A context manager that copies and restores the warnings filter upon
#      |  exiting the context.
#      |
#      |  The 'record' argument specifies whether warnings should be captured by a
#      |  custom implementation of warnings.showwarning() and be appended to a list
#      |  returned by the context manager. Otherwise None is returned by the context
#      |  manager. The objects appended to the list are arguments whose attributes
#      |  mirror the arguments to showwarning().
#      |
#      |  The 'module' argument is to specify an alternative module to the module
#      |  named 'warnings' and imported under that name. This argument is only useful
#      |  when testing the warnings module itself.
#      |
# ...

# %%
warnings.filterwarnings("ignore")

# %%
# parameter grid
parameters = {
    'penalty' : ['l1','l2'], 
    'class_weight': ['dict','balanced'],
    'solver'  : ['newton-cg', 'lbfgs', 'liblinear'],
    'l1_ratio':[0.1, 0.5, 0.7, 0.9, 1]
}

# %%
logreg=LogisticRegression()
clf=GridSearchCV(logreg,# model
param_grid=parameters,#hyperparameters
scoring='accuracy',# metric for scoring
cv=10,# number of folds
verbose=3)

# %%
clf.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV 1/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 6/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 7/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 8/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 9/10] END class_weight=dict, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# ...

# %%
print("Tuned Hyperparameters :", clf.best_params_)
print("Accuracy :",abs(clf.best_score_))
# Out:
# Tuned Hyperparameters : {'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'newton-cg'}
# Accuracy : 0.7596785464709994

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
conf_mat=confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[122,  28],
#        [ 23,  58]], dtype=int64)

# %%
true_positive = conf_mat[0][0]
false_positive = conf_mat[0][1]
false_negative = conf_mat[1][0]
true_negative = conf_mat[1][1]

# %%
print(true_positive,false_positive,false_negative,true_negative)
# Out:
# 122 28 23 58
